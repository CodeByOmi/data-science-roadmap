# %% [markdown]
# ## ORDER DATA ANALYSIS

# %%
# import csv

# with open("order.csv", "r") as file:
#     reader = csv.reader(file)
#     header = next(reader)
#     rows = list(reader)

# print(header)
# print(rows[:8])

# %% [markdown]
# ## reading the csv module
#
# - imported the csv module
# - opened the file in read mode
# - use csv.reader to read rows
# - skip header from data
# - print each row in the form of list

# %%
# total_price = 0

# for row in rows:
#     price = row[2]
#     if price != "":
#         total_price += float(price)

# print("total sales:", total_price)

# %% [markdown]
# ## sales calculation logic
#
# - iterated through each row
# - ignored empty values to avoid errors
# - converted amount from string to float
# - added values to get total sales
